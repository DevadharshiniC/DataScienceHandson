# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Loan_Default.csv')

# %%
data
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
data.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
data.shape
# Out:
# (148670, 34)

# %%
data.drop(columns='ID', inplace=True)
data.drop(columns='year', inplace=True)

# %%
data
# Out:
#        loan_limit             Gender approv_in_adv loan_type loan_purpose  \
# 0              cf  Sex Not Available         nopre     type1           p1
# 1              cf               Male         nopre     type2           p1
# 2              cf               Male           pre     type1           p1
# 3              cf               Male         nopre     type1           p4
# 4              cf              Joint           pre     type1           p1
# ...           ...                ...           ...       ...          ...
# 148665         cf  Sex Not Available         nopre     type1           p3
# 148666         cf               Male         nopre     type1           p1
# 148667         cf               Male         nopre     type1           p4
# 148668         cf             Female         nopre     type1           p4
# 148669         cf             Female         nopre     type1           p3
#
#        Credit_Worthiness open_credit business_or_commercial  loan_amount  \
# ...

# %%
data.isna().sum()
# Out:
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# age                            200
# submission_of_application      200
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['loan_limit'].unique()
# Out:
# array(['cf', nan, 'ncf'], dtype=object)

# %%
data['loan_limit'].value_counts()
# Out:
# cf     135348
# ncf      9978
# Name: loan_limit, dtype: int64

# %%
data['loan_limit'].fillna(data['loan_limit'].mode()[0], inplace = True)

# %%
data['loan_limit'].isna().sum()
# Out:
# 0

# %%
data['approv_in_adv'].unique()
# Out:
# array(['nopre', 'pre', nan], dtype=object)

# %%
data['approv_in_adv'].value_counts()
# Out:
# nopre    124621
# pre       23141
# Name: approv_in_adv, dtype: int64

# %%
data['approv_in_adv'].fillna(data['approv_in_adv'].mode()[0], inplace = True)

# %%
data['approv_in_adv'].isna().sum()
# Out:
# 0

# %%
data['loan_purpose'].unique()
# Out:
# array(['p1', 'p4', 'p3', 'p2', nan], dtype=object)

# %%
data['loan_purpose'].value_counts()
# Out:
# p3    55934
# p4    54799
# p1    34529
# p2     3274
# Name: loan_purpose, dtype: int64

# %%
data['loan_purpose'].fillna(data['loan_purpose'].mode()[0], inplace = True)

# %%
data['loan_purpose'].isna().sum()
# Out:
# 0

# %%
data['rate_of_interest'].mean()
# Out:
# 4.045475804366537

# %%
data['rate_of_interest'].median()
# Out:
# 3.99

# %%
data['rate_of_interest'].plot(kind= 'box')
# Out:
# <AxesSubplot:>

# %%
data['rate_of_interest'] = data['rate_of_interest'].fillna(data['rate_of_interest'].median())

# %%
data['rate_of_interest'].isna().sum()
# Out:
# 0

# %%
data['Interest_rate_spread'].mean()
# Out:
# 0.4416556604868321

# %%
data['Interest_rate_spread'].median()
# Out:
# 0.3904

# %%
data['Interest_rate_spread'].plot(kind= 'box')
# Out:
# <AxesSubplot:>

# %%
data['Interest_rate_spread'] = data['Interest_rate_spread'].fillna(data['Interest_rate_spread'].median())

# %%
data['Interest_rate_spread'].isna().sum()
# Out:
# 0

# %%
data['Upfront_charges'].mean()
# Out:
# 3224.996126591196

# %%
data['Upfront_charges'].median()
# Out:
# 2596.45

# %%
data['Upfront_charges'].plot(kind= 'box')
# Out:
# <AxesSubplot:>

# %%
data['Upfront_charges'] = data['Upfront_charges'].fillna(data['Upfront_charges'].median())

# %%
data['Upfront_charges'].isna().sum()
# Out:
# 0

# %%
data['property_value'].mean()
# Out:
# 497893.46569640347

# %%
data['property_value'].median()
# Out:
# 418000.0

# %%
data['property_value'].plot(kind= 'box')
# Out:
# <AxesSubplot:>

# %%
data['property_value'] = data['property_value'].fillna(data['property_value'].median())

# %%
data['property_value'].isna().sum()
# Out:
# 0

# %%
data['income']
# Out:
# 0          1740.0
# 1          4980.0
# 2          9480.0
# 3         11880.0
# 4         10440.0
#            ...
# 148665     7860.0
# 148666     7140.0
# 148667     6900.0
# 148668     7140.0
# 148669     7260.0
# Name: income, Length: 148670, dtype: float64

# %%
data['income'].mean()
# Out:
# 6957.338876146789

# %%
data['income'].median()
# Out:
# 5760.0

# %%
data['income'].plot(kind= 'box')
# Out:
# <AxesSubplot:>

# %%
data['income'] = data['income'].fillna(data['income'].median())

# %%
data['income'].isna().sum()
# Out:
# 0

# %%
data.dropna(subset=['age','submission_of_application','term','Neg_ammortization'],inplace=True)

# %%
data['LTV'].mean()
# Out:
# 72.73932669813621

# %%
data['LTV'].median()
# Out:
# 75.12254902

# %%
data['LTV'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data['LTV'] = data['LTV'].fillna(data['LTV'].median())

# %%
data['LTV'].isna().sum()
# Out:
# 0

# %%
data['dtir1'].mean()
# Out:
# 37.73393993955373

# %%
data['dtir1'].median()
# Out:
# 39.0

# %%
data['dtir1'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data['dtir1'] = data['dtir1'].fillna(data['dtir1'].median())

# %%
data['dtir1'].isna().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# loan_limit                   0
# Gender                       0
# approv_in_adv                0
# loan_type                    0
# loan_purpose                 0
# Credit_Worthiness            0
# open_credit                  0
# business_or_commercial       0
# loan_amount                  0
# rate_of_interest             0
# Interest_rate_spread         0
# Upfront_charges              0
# term                         0
# Neg_ammortization            0
# interest_only                0
# lump_sum_payment             0
# property_value               0
# construction_type            0
# occupancy_type               0
# Secured_by                   0
# total_units                  0
# income                       0
# credit_type                  0
# Credit_Score                 0
# co-applicant_credit_type     0
# age                          0
# submission_of_application    0
# LTV                          0
# Region                       0
# Security_Type                0
# ...

# %%
data.shape
# Out:
# (148308, 32)

# %%
data['Gender'].unique()
# Out:
# array(['Sex Not Available', 'Male', 'Joint', 'Female'], dtype=object)

# %%
data['Gender'].replace({'Sex Not Available':'Others','Joint':'Others'},inplace=True)

# %%
data['Gender'].value_counts()
# Out:
# Others    78776
# Male      42297
# Female    27235
# Name: Gender, dtype: int64

# %%
data['total_units'] = data['total_units'].str.replace('U','')

# %%
data['total_units']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 148665    1
# 148666    4
# 148667    1
# 148668    1
# 148669    1
# Name: total_units, Length: 148308, dtype: object

# %%
data_num = data.select_dtypes(include = np.number)

# %%
data_num
# Out:
#         loan_amount  rate_of_interest  Interest_rate_spread  Upfront_charges  \
# 0            116500             3.990                0.3904          2596.45
# 1            206500             3.990                0.3904          2596.45
# 2            406500             4.560                0.2000           595.00
# 3            456500             4.250                0.6810          2596.45
# 4            696500             4.000                0.3042             0.00
# ...             ...               ...                   ...              ...
# 148665       436500             3.125                0.2571          9960.00
# 148666       586500             5.190                0.8544             0.00
# 148667       446500             3.125                0.0816          1226.64
# 148668       196500             3.500                0.5824          4323.33
# 148669       406500             4.375                1.3871          6000.00
#
# ...

# %%
data_cat = data.select_dtypes(exclude = np.number)

# %%
data_cat
# Out:
#        loan_limit  Gender approv_in_adv loan_type loan_purpose  \
# 0              cf  Others         nopre     type1           p1
# 1              cf    Male         nopre     type2           p1
# 2              cf    Male           pre     type1           p1
# 3              cf    Male         nopre     type1           p4
# 4              cf  Others           pre     type1           p1
# ...           ...     ...           ...       ...          ...
# 148665         cf  Others         nopre     type1           p3
# 148666         cf    Male         nopre     type1           p1
# 148667         cf    Male         nopre     type1           p4
# 148668         cf  Female         nopre     type1           p4
# 148669         cf  Female         nopre     type1           p3
#
#        Credit_Worthiness open_credit business_or_commercial Neg_ammortization  \
# 0                     l1        nopc                  nob/c           not_neg
# ...

# %% [markdown]
# # Exploratory Data analysis

# %%
for col in data.select_dtypes(include = np.number).columns:
    print(col)
    sns.histplot(data[col])
    plt.show()
# Out:
# loan_amount
# rate_of_interest
# Interest_rate_spread
# Upfront_charges
# term
# property_value
# income
# Credit_Score
# LTV
# Status
# dtir1

# %%
for col in data.select_dtypes(include = np.number).columns:
    print(col)
    sns.boxplot(data[col])
    plt.show()
# Out:
# loan_amount
# C:\Users\devad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# rate_of_interest
# C:\Users\devad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Interest_rate_spread
# ...

# %%
for col in data.select_dtypes(exclude = np.number).columns:
    print(col)
    plt.figure(figsize=(10,10))
    sns.countplot(data[col], order=data[col].value_counts().index)
    plt.show()
# Out:
# C:\Users\devad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# loan_limit
# C:\Users\devad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Gender
# C:\Users\devad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
sns.pairplot(data)

# %%
data.groupby('Region')['Upfront_charges'].mean().sort_values(ascending = False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
data.groupby('Gender')['income'].mean().sort_values(ascending = False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148308 entries, 0 to 148669
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   loan_limit                 148308 non-null  object
#  1   Gender                     148308 non-null  object
#  2   approv_in_adv              148308 non-null  object
#  3   loan_type                  148308 non-null  object
#  4   loan_purpose               148308 non-null  object
#  5   Credit_Worthiness          148308 non-null  object
#  6   open_credit                148308 non-null  object
#  7   business_or_commercial     148308 non-null  object
#  8   loan_amount                148308 non-null  int64
#  9   rate_of_interest           148308 non-null  float64
#  10  Interest_rate_spread       148308 non-null  float64
#  11  Upfront_charges            148308 non-null  float64
#  12  term                       148308 non-null  float64
# ...

# %%
data.select_dtypes(include = np.number).corr()
# Out:
#                       loan_amount  rate_of_interest  Interest_rate_spread  \
# loan_amount              1.000000         -0.122638             -0.309500
# rate_of_interest        -0.122638          1.000000              0.615966
# Interest_rate_spread    -0.309500          0.615966              1.000000
# Upfront_charges          0.057069         -0.070771              0.035723
# term                     0.174530          0.183071             -0.137294
# property_value           0.685774         -0.102440             -0.286880
# income                   0.440835         -0.014247             -0.099594
# Credit_Score             0.004362         -0.001433             -0.001702
# LTV                      0.036472         -0.002431              0.036502
# Status                  -0.035390         -0.048065             -0.049347
# dtir1                    0.015018          0.029937              0.050110
#
#                       Upfront_charges      term  property_value    income  \
# ...

# %%
sns.heatmap(data.select_dtypes(include = np.number).corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#        loan_limit  Gender approv_in_adv loan_type loan_purpose  \
# 0              cf  Others         nopre     type1           p1
# 1              cf    Male         nopre     type2           p1
# 2              cf    Male           pre     type1           p1
# 3              cf    Male         nopre     type1           p4
# 4              cf  Others           pre     type1           p1
# ...           ...     ...           ...       ...          ...
# 148665         cf  Others         nopre     type1           p3
# 148666         cf    Male         nopre     type1           p1
# 148667         cf    Male         nopre     type1           p4
# 148668         cf  Female         nopre     type1           p4
# 148669         cf  Female         nopre     type1           p3
#
#        Credit_Worthiness open_credit business_or_commercial  loan_amount  \
# 0                     l1        nopc                  nob/c       116500
# ...

# %%
data_encoded = pd.get_dummies(data.select_dtypes(exclude = np.number))

# %%
pd.concat([data.select_dtypes(include = np.number),data_encoded], axis = 1)
# Out:
#         loan_amount  rate_of_interest  Interest_rate_spread  Upfront_charges  \
# 0            116500             3.990                0.3904          2596.45
# 1            206500             3.990                0.3904          2596.45
# 2            406500             4.560                0.2000           595.00
# 3            456500             4.250                0.6810          2596.45
# 4            696500             4.000                0.3042             0.00
# ...             ...               ...                   ...              ...
# 148665       436500             3.125                0.2571          9960.00
# 148666       586500             5.190                0.8544             0.00
# 148667       446500             3.125                0.0816          1226.64
# 148668       196500             3.500                0.5824          4323.33
# 148669       406500             4.375                1.3871          6000.00
#
# ...

# %% [markdown]
# 1. Northern region has a maximum count
# 2. People of age group 45-54 years shows maximum participation
# 3. CIB credit_type is preferred
# 4. loan_type - type 1
# 5. loan_purpose - p3
